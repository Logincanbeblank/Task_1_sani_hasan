# %% [markdown]
# <a href="https://colab.research.google.com/github/Logincanbeblank/Task_1_sani_hasan/blob/main/Task_2_My_contribution_Sani_Hasan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# fetching dataset - 1 Automobile buying behaviours
df1 = pd.read_csv('/content/Indian automoble buying behavour study 1.0.csv')
df1.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
# fetching dataset - 2 electric vehicle charging stations
df2 = pd.read_csv('/content/electric_vehicle_charging_station_list.csv')
df2.head()
# Out:
#    no region                                            address  \
# 0   1   NDMC  Prithviraj Market, Rabindra Nagar, New Delhi- ...
# 1   2   NDMC  Prithviraj Market, Rabindra Nagar, New Delhi- ...
# 2   3   NDMC  Outside RWA Park, Jor Bagh Market, Jor Bagh Co...
# 3   4   NDMC  Opposite Dory Pharmacy, Khanna Market, Aliganj...
# 4   5   NDMC  Opposite Goel Opticals, Khanna Market, Aliganj...
#
#                                           aux addres   latitude  longitude  \
# 0  Electric Vehicle Charger, Prithviraj Market, R...  28.600725  77.226252
# 1  Electric Vehicle Charger, Prithviraj Market, R...  28.600725  77.226252
# 2  Electric Vehicle Charger, Outside RWA Park, Jo...  28.588303  77.217697
# 3  Electric Vehicle Charger, Opposite Dory Pharma...  28.582654  77.220087
# 4  Electric Vehicle Charger, Opposite Goel Optica...  28.584485  77.220316
#
#      type  power       service
# 0  DC-001  15 kW  Self Service
# 1  DC-001  15 kW  Self Service
# 2  DC-001  15 kW  Self Service
# ...

# %%
# fetching dataset - 3 india districs census
df3 = pd.read_csv('/content/EV Stats-1.csv')
df3.head()
# Out:
#    Sl. No           State  \
# 0       1  Andhra Pradesh
# 1       2           Assam
# 2       3           Bihar
# 3       4    Chhattisgarh
# 4       5           Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                                431
# 1                                                463
# 2                                                252
# 3                                                613
# 4                                               1395
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                                692
# 1                                138
# 2                                430
# 3                                382
# 4                                251
#
#    Two Wheelers (Max power not exceeding 250 Watts)  \
# 0                                              4689
# 1                                              1006
# 2                                              2148
# ...

# %%
# fetching dataset - 4 EV market India dataset
df4 = pd.read_excel('/content/3_ev_market_india_dataset.xlsx')
df4.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Efficiency_WhKm  FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161             940         Yes        AWD
# 1       270              167             250          No        RWD
# 2       400              181             620         Yes        AWD
# 3       360              206             560         Yes        RWD
# 4       170              168             190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
#EDA
# checking the shape (# of rows and columns) of the datasets
print('DF1 Shape: ', df1.shape)
print('DF2 Shape: ', df2.shape)
print('DF3 Shape: ', df3.shape)
print('DF4 Shape: ', df4.shape)
# Out:
# DF1 Shape:  (99, 13)
# DF2 Shape:  (202, 9)
# DF3 Shape:  (31, 10)
# DF4 Shape:  (103, 14)

# %%
# checking the info (columns, datatypes, nulls) of the datasets
print(' <<< DATASET 1 -----------------------------------------------------------')
print(df1.info())
print(' <<< DATASET 2 -----------------------------------------------------------')
print(df2.info())
print(' <<< DATASET 3 -----------------------------------------------------------')
print(df3.info())
print(' <<< DATASET 4 -----------------------------------------------------------')
print(df4.info())
# Out:
#  <<< DATASET 1 -----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB
# None
# ...

# %%
# getting a statistical summary of the datasets
d1 = df1.describe()
d2 = df2.describe()
d3 = df3.describe()
d4 = df4.describe()
display('<<< DATASET 1 >>>', d1, '<<< DATASET 2 >>>', d2, '<<< DATASET 3 >>>', d3, '<<<DATASET 4>>>',d4)
# Out:
# '<<< DATASET 1 >>>'
#              Age  No of Dependents        Salary   Wife Salary  Total Salary  \
# count  99.000000         99.000000  9.900000e+01  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  1.736364e+06  5.343434e+05  2.270707e+06
# std     6.246054          1.335265  6.736217e+05  6.054450e+05  1.050777e+06
# min    26.000000          0.000000  2.000000e+05  0.000000e+00  2.000000e+05
# 25%    31.000000          2.000000  1.300000e+06  0.000000e+00  1.550000e+06
# 50%    36.000000          2.000000  1.600000e+06  5.000000e+05  2.100000e+06
# 75%    41.000000          3.000000  2.200000e+06  9.000000e+05  2.700000e+06
# max    51.000000          4.000000  3.800000e+06  2.100000e+06  5.200000e+06
#
#               Price
# count  9.900000e+01
# mean   1.194040e+06
# std    4.376955e+05
# min    1.100000e+05
# 25%    8.000000e+05
# 50%    1.200000e+06
# 75%    1.500000e+06
# max    3.000000e+06
# '<<< DATASET 2 >>>'
# ...

# %%
#First we must consider the type of EV popular by state
#First Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: 2 Wheelers (Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules)', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Electric Vehicles (2 Wheelers) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Statistically Gujarat, Haryana and UP have the most 2 wheeler EVs
#Now we check similarly for the sub divisions of the two wheelers which is Category L2 (CMVR)
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Two Wheelers (Category L2 (CMVR))', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: 2 Wheelers', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Statewise Electric Vehicles (2 Wheelers Category L2 (CMVR) in India', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Two Wheelers (Max power not exceeding 250 Watts)
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Two Wheelers (Max power not exceeding 250 Watts)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV: 2 Wheelers', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Two Wheelers (Max power not exceeding 250 Watts)', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#After this we can see which type of 2 wheeler is prevalent in which state which leaves up with Gujarat Haryana and UP for the top three states for L1 and L2 type, Gujarat, Haryana, Up and Maharashtra for the L2 CMVR type and Gujarat, Haryana, Maharashtra, UP and West Bengal in Evs not exceeding 250 Watts.
#Now we perform a similar analysis for 3 Wheelers and so on
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Two Wheelers (Max power not exceeding 250 Watts)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Three Wheelers (Category L5 slow speed as per CMVR)', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Three Wheelers (Category L5 as per CMVR)
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Three Wheelers (Category L5 as per CMVR)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Three Wheelers (Category L5 as per CMVR)', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Passenger Cars (Category M1 as per CMVR)
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Passenger Cars (Category M1 as per CMVR)', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Passenger Cars (Category M1 as per CMVR)', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Buses
plt.figure(figsize=(6, 6))
sns.barplot(data=df3, y=df3['State'], x='Buses', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of EV', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Buses', weight=200, family='serif', size=15, pad=12)
plt.show()

# %%
#Now we check the Indian automobile buying data to ascertain what type of vehicles are more likely to be preferred by what customer base.
sns.catplot(data=df1, x='Make', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Make',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of cars bought overtime', family='serif', size=15)
plt.show()

# %%
#now we check the reason for the above plot which is the no. of dependents
sns.catplot(data=df1, x='No of Dependents', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('No of Dependents',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of cars bought overtime', family='serif', size=15)
plt.show()

# %%
plt.figure(figsize=(7, 7))
sns.barplot(data=df1, y=df1['No of Dependents'], x='Make', palette='viridis')
plt.ylabel('No of Dependents', fontsize=14, family='serif')
plt.xlabel('Make', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='No of Dependents vs the cars bought', weight=200, family='serif', size=15, pad=12)
plt.show()

# %% [markdown]
# The above graphs tell us that the number of dependents changes the type of vehicle that people will buy, where lesser no. of dependents will prompt smaller models vs more no. of dependents will prompt the larger models of the car. This will hold true to the EV variant of this as well.

# %% [markdown]
# Now we check the no. of charging stations in the country to check the most ease of acess for consumers.

# %%
sns.catplot(data=df2, x='region', kind='count', palette='viridis', height=6, aspect=2)
sns.despine(right=False, top=False)
plt.tick_params(axis='x', rotation=40)
plt.xlabel('Regions',family='serif', size=12)
plt.ylabel('Count', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title('Number of charging stations per Region', family='serif', size=15)
plt.show()

# %% [markdown]
# The above plot shows the regions which have a more condensed placement of the charging stations allowing for ease of charging in case of problems for EVs this shows these regions are well suited to host a higher no of EVs and will also boast an exceptional diversity in the EV types.

# %%
#pricing for the EV cars
plt.plot(df4['PriceEuro'], color='blue')
plt.xlabel('Number of Samples', family='serif', size=12)
plt.ylabel('Price', family='serif', size=12)
plt.title('Price Comparison', family='serif', size=15, pad=12);

# %%
#pricing for the non EV cars
# plotting the price from dataset 3
plt.plot(df1['Price'], color='red')
plt.xlabel('Number of Samples', family='serif', size=12)
plt.ylabel('Price', family='serif', size=12)
plt.title('Price Comparison', family='serif', size=15, pad=12);

# %% [markdown]
# Building a model

# %%
# selecting features for building a model
X =df3[['Total in state','Passenger Cars (Category M1 as per CMVR)','Two Wheelers (Max power not exceeding 250 Watts)','Three Wheelers (Category L5 as per CMVR)','Buses','Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules','Three Wheelers (Category L5 slow speed as per CMVR)']]

# %%
# feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=7)
X_pca = pca.fit_transform(X_scaled)
df_pca = pd.DataFrame(X_pca, columns=['PC1', 'PC2', 'PC3','PC4','PC5','PC6','PC7'])
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7
# 0 -0.646848 -0.020383  0.198448  0.023438 -0.137246  0.054805  0.003088
# 1 -0.515693 -0.235117 -0.359356 -0.669041  0.111279  0.020041 -0.001606
# 2 -0.619772 -0.162564 -0.215841 -0.302420  0.015482  0.040781  0.002888
# 3 -0.178521 -0.486492 -0.695971 -0.099197  0.102714 -0.169169 -0.008079
# 4  0.869603  3.145294 -0.508324  0.169385  0.120376  0.028344  0.000405

# %%
# plotting the results of Elbow

wcss = []

for i in range(1, 11):
  kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
  kmean.fit(X_pca)
  wcss.append(kmean.inertia_)

plt.figure(figsize=(8,6))
plt.title('Plot of the Elbow Method', size=15, family='serif')
plt.plot(range(1, 11), wcss)
plt.xticks(range(1, 11), family='serif')
plt.yticks(family='serif')
plt.xlabel('Number of Custers (K)', family='serif')
plt.ylabel('WCSS', family='serif')
plt.grid()
plt.tick_params(axis='both', direction='inout', length=6, color='Red', grid_color='black', grid_linestyle='-')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# training the model using k=4 as rendered by the above plot
kmean = KMeans(n_clusters=4, init='k-means++', random_state=90)
kmean.fit(X_pca)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=90)

# %%
# check the labels assigned to each data point
print(kmean.labels_)
# Out:
# [2 2 2 2 3 2 0 0 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 1]

# %%
# check the size of clusters
pd.Series(kmean.labels_).value_counts()
# Out:
# 2    25
# 0     4
# 3     1
# 1     1
# dtype: int64

# %%
# adding a new feature of cluster labels to the dataset 3
df3['clusters'] = kmean.labels_

# %%
# visualizing clusters
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_pca, x='PC1', y='PC7', s=70, hue=kmean.labels_, palette='viridis', zorder=2, alpha=.9)
plt.scatter(x=kmean.cluster_centers_[:,0], y=kmean.cluster_centers_[:,1], marker="*", c="r", s=80, label="centroids")
plt.xlabel('PC1', family='serif', size=12)
plt.ylabel('PC7', family='serif', size=12)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.grid()
plt.tick_params(grid_color='lightgray', grid_linestyle='-', zorder=1)
plt.legend(title='Labels', fancybox=True, shadow=True)
plt.title('K-Means Clustering Results', family='serif', size=15)
plt.show()
